# %%
from dotenv import load_dotenv
import os
import requests
from datetime import datetime
import xmltodict
from urllib.parse import quote


# Loading variables from .env

load_dotenv()

DB_CLIENT_ID = os.getenv("DB_CLIENT_ID")
DB_API_KEY   = os.getenv("DB_CLIENT_API_KEY")

if not DB_CLIENT_ID or not DB_API_KEY:
    raise RuntimeError("DB_CLIENT_ID or DB_API_KEY not set. Did you create the .env file?")

# Endpoint to access DB timetable data

BASE_URL = "https://apis.deutschebahn.com/db-api-marketplace/apis/timetables/v1"

HEADERS = {
    "DB-Client-Id": DB_CLIENT_ID,
    "DB-Api-Key": DB_API_KEY,
    "Accept": "application/xml"
}

def search_station(pattern: str) -> str:
    """Look up EVA number for a station name."""
    url = f"{BASE_URL}/station/{quote(pattern)}"
    request = requests.get(url, headers=HEADERS, timeout = 20)
    request.raise_for_status()
    eva = xmltodict.parse(request.text)["stations"]["station"]["@eva"]
    return eva

def get_plan(eva: str, when: datetime) -> str:
    """Fetch timetable plan XML for given EVA + datetime."""
    yymmdd = when.strftime("%y%m%d")
    hour   = when.strftime("%H")
    url = f"{BASE_URL}/plan/{eva}/{yymmdd}/{hour}"
    response = requests.get(url, headers=HEADERS, timeout=30)
    response.raise_for_status()
    return response.text  # XML string


# Questionnaire to get station and specific time frame in which you want all departures

if __name__ == "__main__":
    station_name = input("Station name: ")
    date_str     = input("Date (YYYY-MM-DD): ")
    hour_str     = input("Hour (00-23): ")

    dt = datetime.strptime(f"{date_str} {hour_str}", "%Y-%m-%d %H")

    eva = search_station(station_name)
    print(f"EVA for {station_name}: {eva}")
    plan = xmltodict.parse(get_plan(eva, dt))
# Out:
# Station name:  Dresden Hbf
# Date (YYYY-MM-DD):  2025-08-27
# Hour (00-23):  16
# EVA for Dresden Hbf: 8010085

# %%
services = plan['timetable']["s"]

# %%
services
# Out:
# [{'@id': '-1728110115647623981-2508271653-1',
#   'tl': {'@t': 'p', '@o': 'LD', '@c': 'TL', '@n': '76529'},
#   'dp': {'@pt': '2508271653',
#    '@pp': '14',
#    '@l': 'RB60',
#    '@ppth': 'Dresden Mitte|Dresden-Neustadt|Dresden Industriegelände|Dresden-Klotzsche|Langebrück(Sachs)|Radeberg|Arnsdorf(Dresden)|Großharthau|Weickersdorf(Sachs)|Bischofswerda|Demitz-Thumitz|Seitschen|Bautzen|Kubschütz|Pommritz|Breitendorf|Löbau(Sachs)|Zoblitz|Reichenbach(Oberlausitz)|Gersdorf(Görlitz)|Görlitz-Rauschwalde|Görlitz'}},
#  {'@id': '5890303731005091364-2508271436-21',
#   'tl': {'@t': 'p', '@o': 'LD', '@c': 'TL', '@n': '20860'},
#   'ar': {'@pt': '2508271603',
#    '@pp': '13',
#    '@l': 'RB61',
#    '@ppth': 'Ebersbach(Sachs)|Neusalza-Spremberg|Taubenheim(Spree)|Sohland|Schirgiswalde-Kirschau|Wilthen|Neukirch(Lausitz)Ost|Neukirch(Lausitz)West|Putzkau|Schmölln(Ol)|Bischofswerda|Weickersdorf(Sachs)|Großharthau|Arnsdorf(Dresden)|Radeberg|Langebrück(Sachs)|Dresden-Klotzsche|Dresden Industriegelände|Dresden-Neustadt|Dresden Mitte'}},
#  {'@id': '7460258561213142904-2508271623-10',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '32752'},
#   'ar': {'@pt': '2508271646',
#    '@pp': '14',
#    '@l': '2',
#    '@ppth': 'Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271648',
#    '@pp': '14',
#    '@l': '2',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Industriegelände|Dresden-Klotzsche|Dresden Grenzstraße|Dresden Flughafen'}},
#  {'@id': '3639185015027004194-2508271610-1',
#   'tl': {'@f': 'F', '@t': 'p', '@o': '80', '@c': 'ICE', '@n': '1554'},
#   'dp': {'@pt': '2508271610',
#    '@pp': '3',
#    '@ppth': 'Dresden-Neustadt|Riesa|Leipzig Hbf|Erfurt Hbf|Gotha|Eisenach Hbf|Bad Hersfeld|Fulda|Frankfurt(Main)Hbf|Frankfurt(M) Flughafen Fernbf|Mainz Hbf|Wiesbaden Hbf'}},
#  {'@id': '-3038006905450529934-2508271635-1',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '8004L1', '@c': 'S', '@n': '16625'},
#   'dp': {'@pt': '2508271635',
#    '@pp': '10',
#    '@l': '8',
#    '@ppth': 'Dresden Mitte|Dresden-Neustadt|Dresden Industriegelände|Dresden-Klotzsche|Langebrück(Sachs)|Radeberg|Kleinröhrsdorf|Großröhrsdorf|Pulsnitz Süd|Pulsnitz|Bischheim-Gersdorf|Kamenz(Sachs)'}},
#  {'@id': '4558275999006255649-2508270642-28',
#   'tl': {'@f': 'F', '@t': 'p', '@o': '80', '@c': 'IC', '@n': '2441'},
#   'ar': {'@pt': '2508271639',
#    '@pp': '3',
#    '@ppth': 'Frankfurt(Main)Hbf|Frankfurt(M) Flughafen Fernbf|Mainz Hbf|Boppard Hbf|Koblenz Hbf|Bonn Hbf|Köln Hbf|Düsseldorf Hbf|Duisburg Hbf|Essen Hbf|Bochum Hbf|Dortmund Hbf|Hamm(Westf)Hbf|Gütersloh Hbf|Bielefeld Hbf|Herford|Bad Oeynhausen|Minden(Westf)|Hannover Hbf|Braunschweig Hbf|Magdeburg Hbf|Köthen|Halle(Saale)Hbf|Leipzig/Halle Flughafen|Leipzig Hbf|Riesa|Dresden-Neustadt'}},
#  {'@id': '3355093545386318948-2508271634-1',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '33024'},
#   'dp': {'@pt': '2508271634',
#    '@pp': '7',
#    '@l': '3',
#    '@ppth': 'Dresden-Plauen|Freital-Potschappel|Freital-Deuben|Freital-Hainsberg|Freital-Hainsberg West|Tharandt|Edle Krone|Klingenberg-Colmnitz|Niederbobritzsch|Muldenhütten|Freiberg(Sachs)'}},
#  {'@id': '3109835488225486737-2508270730-18',
#   'tl': {'@f': 'F', '@t': 'p', '@o': '55', '@c': 'EC', '@n': '172'},
#   'ar': {'@pt': '2508271650',
#    '@pp': '12',
#    '@ppth': 'Budapest-Nyugati|Vac|Nagymaros-Visegrad|Szob|Sturovo|Nove Zamky|Bratislava hl.st.|Kuty|Breclav|Brno hl.n.|Pardubice hl.n.|Kolin(CZ)|Praha hl.n.|Praha-Holesovice|Usti nad Labem hl.n.|Decin hl.n.|Bad Schandau'},
#   'dp': {'@pt': '2508271655',
#    '@pp': '12',
#    '@ppth': 'Dresden-Neustadt|Berlin Südkreuz|Berlin Hbf'}},
#  {'@id': '-4019654002306704576-2508271553-10',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '32750'},
#   'ar': {'@pt': '2508271616',
#    '@pp': '14',
#    '@l': '2',
#    '@ppth': 'Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271618',
#    '@pp': '14',
#    '@l': '2',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Industriegelände|Dresden-Klotzsche|Dresden Grenzstraße|Dresden Flughafen'}},
#  {'@id': '-3245311382640914196-2508271608-1',
#   'tl': {'@f': 'N', '@t': 'p', '@o': 'CXRB', '@c': 'RB', '@n': '74066'},
#   'dp': {'@pt': '2508271608',
#    '@pp': '7',
#    '@l': '30',
#    '@ppth': 'Dresden-Plauen|Freital-Potschappel|Freital-Deuben|Freital-Hainsberg|Freital-Hainsberg West|Tharandt|Edle Krone|Klingenberg-Colmnitz|Niederbobritzsch|Muldenhütten|Freiberg(Sachs)|Kleinschirma|Frankenstein(Sachs)|Oederan|Falkenau(Sachs)Süd|Flöha|Niederwiesa|Chemnitz-Hilbersdorf|Chemnitz Hbf|Chemnitz Süd|Chemnitz Mitte|Chemnitz-Schönau|Chemnitz-Siegmar|Grüna(Sachs)Hp|Wüstenbrand|Hohenstein-Ernstthal|St Egidien|Glauchau(Sachs)|Glauchau-Schönbörnchen|Mosel|Oberrothenbach|Zwickau-Pölbitz|Zwickau(Sachs)Hbf'}},
#  {'@id': '4583249899268847651-2508271548-8',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '32747'},
#   'ar': {'@pt': '2508271608',
#    '@pp': '13',
#    '@l': '2',
#    '@ppth': 'Dresden Flughafen|Dresden Grenzstraße|Dresden-Klotzsche|Dresden Industriegelände|Dresden-Neustadt|Dresden Mitte|Dresden Freiberger Straße'},
#   'dp': {'@pt': '2508271610',
#    '@pp': '13',
#    '@l': '2',
#    '@ppth': 'Dresden-Strehlen|Dresden-Reick|Dresden-Dobritz|Dresden-Niedersedlitz|Dresden-Zschachwitz|Heidenau|Heidenau Süd|Heidenau-Großsedlitz|Pirna'}},
#  {'@id': '-635651003024431168-2508271532-13',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '8004L1', '@c': 'S', '@n': '16622'},
#   'ar': {'@pt': '2508271622',
#    '@pp': '10',
#    '@l': '8',
#    '@ppth': 'Kamenz(Sachs)|Bischheim-Gersdorf|Pulsnitz|Pulsnitz Süd|Großröhrsdorf|Kleinröhrsdorf|Radeberg|Langebrück(Sachs)|Dresden-Klotzsche|Dresden Industriegelände|Dresden-Neustadt|Dresden Mitte'}},
#  {'@id': '5541021131570588780-2508271615-1',
#   'tl': {'@f': 'N', '@t': 'p', '@o': '800456', '@c': 'RE', '@n': '16524'},
#   'dp': {'@pt': '2508271615',
#    '@pp': '9',
#    '@l': '50',
#    '@ppth': 'Dresden Mitte|Dresden-Neustadt|Radebeul Ost|Coswig(b Dresden)|Weinböhla Hp|Niederau|Priestewitz|Nünchritz|Glaubitz(Riesa)|Riesa|Oschatz|Dahlen(Sachs)|Kühren|Wurzen|Borsdorf(Sachs)|Leipzig-Engelsdorf|Leipzig Hbf'}},
#  {'@id': '-3608962032802858857-2508271614-15',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '31750'},
#   'ar': {'@pt': '2508271658',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Bad Schandau|Königstein(Sächs Schw)|Kurort Rathen|Stadt Wehlen(Sachs)|Obervogelgesang|Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271700',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Bischofsplatz|Dresden-Pieschen|Dresden-Trachau|Radebeul Ost|Radebeul-Weintraube|Radebeul-Kötzschenbroda|Radebeul-Zitzschewig|Coswig(b Dresden)|Neusörnewitz|Meißen|Meißen Altstadt|Meißen Triebischtal'}},
#  {'@id': '-5299089345261938657-2508271604-12',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '8004L1', '@c': 'S', '@n': '16752'},
#   'ar': {'@pt': '2508271651',
#    '@pp': '10',
#    '@l': '8',
#    '@ppth': 'Kamenz(Sachs)|Bischheim-Gersdorf|Pulsnitz|Pulsnitz Süd|Großröhrsdorf|Radeberg|Langebrück(Sachs)|Dresden-Klotzsche|Dresden Industriegelände|Dresden-Neustadt|Dresden Mitte'}},
#  {'@id': '-1476504383799491470-2508271652-1',
#   'tl': {'@f': 'N', '@t': 'p', '@o': 'CXRE', '@c': 'RE', '@n': '74026'},
#   'dp': {'@pt': '2508271652',
#    '@pp': '6',
#    '@l': '3',
#    '@ppth': 'Tharandt|Freiberg(Sachs)|Flöha|Chemnitz Hbf|Hohenstein-Ernstthal|Glauchau(Sachs)|Zwickau(Sachs)Hbf|Reichenbach(Vogtl) ob Bf|Plauen(Vogtl) ob Bf|Hof Hbf'}},
#  {'@id': '-5796525866906815524-2508271525-11',
#   'tl': {'@f': 'D', '@t': 'p', '@o': 'LDTLX', '@c': 'TLX', '@n': '20850'},
#   'ar': {'@pt': '2508271632',
#    '@pp': '13',
#    '@l': 'RE2',
#    '@ppth': 'Ebersbach(Sachs)|Sohland|Wilthen|Neukirch(Lausitz)Ost|Bischofswerda|Arnsdorf(Dresden)|Radeberg|Dresden-Klotzsche|Dresden-Neustadt|Dresden Mitte'}},
#  {'@id': '-4151459214150759042-2508271617-16',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '31751'},
#   'ar': {'@pt': '2508271657',
#    '@pp': '13',
#    '@l': '1',
#    '@ppth': 'Meißen Triebischtal|Meißen Altstadt|Meißen|Neusörnewitz|Coswig(b Dresden)|Radebeul-Zitzschewig|Radebeul-Kötzschenbroda|Radebeul-Weintraube|Radebeul Ost|Dresden-Trachau|Dresden-Pieschen|Dresden Bischofsplatz|Dresden-Neustadt|Dresden Mitte|Dresden Freiberger Straße'},
#   'dp': {'@pt': '2508271659',
#    '@pp': '13',
#    '@l': '1',
#    '@ppth': 'Dresden-Strehlen|Dresden-Reick|Dresden-Dobritz|Dresden-Niedersedlitz|Dresden-Zschachwitz|Heidenau|Heidenau Süd|Heidenau-Großsedlitz|Pirna|Obervogelgesang|Stadt Wehlen(Sachs)|Kurort Rathen|Königstein(Sächs Schw)|Bad Schandau'}},
#  {'@id': '7476557392887065358-2508271544-15',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '31748'},
#   'ar': {'@pt': '2508271628',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Bad Schandau|Königstein(Sächs Schw)|Kurort Rathen|Stadt Wehlen(Sachs)|Obervogelgesang|Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271630',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Bischofsplatz|Dresden-Pieschen|Dresden-Trachau|Radebeul Ost|Radebeul-Weintraube|Radebeul-Kötzschenbroda|Radebeul-Zitzschewig|Coswig(b Dresden)|Neusörnewitz|Meißen|Meißen Altstadt|Meißen Triebischtal'}},
#  {'@id': '-6342999213792240687-2508271439-34',
#   'tl': {'@f': 'N', '@t': 'p', '@o': 'CXRB', '@c': 'RB', '@n': '74063'},
#   'ar': {'@pt': '2508271650',
#    '@pp': '7',
#    '@l': '30',
#    '@ppth': 'Zwickau(Sachs)Hbf|Zwickau-Pölbitz|Oberrothenbach|Mosel|Glauchau-Schönbörnchen|Glauchau(Sachs)|St Egidien|Hohenstein-Ernstthal|Wüstenbrand|Grüna(Sachs)Hp|Chemnitz-Siegmar|Chemnitz-Schönau|Chemnitz Mitte|Chemnitz Süd|Chemnitz Hbf|Chemnitz-Hilbersdorf|Niederwiesa|Flöha|Falkenau(Sachs)Süd|Oederan|Frankenstein(Sachs)|Kleinschirma|Freiberg(Sachs)|Muldenhütten|Niederbobritzsch|Klingenberg-Colmnitz|Edle Krone|Tharandt|Freital-Hainsberg West|Freital-Hainsberg|Freital-Deuben|Freital-Potschappel|Dresden-Plauen'}},
#  {'@id': '-6539337888998147826-2508271537-12',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '33023'},
#   'ar': {'@pt': '2508271622',
#    '@pp': '7',
#    '@l': '3',
#    '@ppth': 'Freiberg(Sachs)|Muldenhütten|Niederbobritzsch|Klingenberg-Colmnitz|Edle Krone|Tharandt|Freital-Hainsberg West|Freital-Hainsberg|Freital-Deuben|Freital-Potschappel|Dresden-Plauen'}},
#  {'@id': '542688358933670490-2508271623-1',
#   'tl': {'@f': 'D', '@t': 'p', '@o': 'LDTLX', '@c': 'TLX', '@n': '26907'},
#   'dp': {'@pt': '2508271623',
#    '@pp': '14',
#    '@l': 'RE1',
#    '@ppth': 'Dresden Mitte|Dresden-Neustadt|Dresden-Klotzsche|Radeberg|Arnsdorf(Dresden)|Bischofswerda|Bautzen|Löbau(Sachs)|Görlitz'}},
#  {'@id': '-678599235754789523-2508271500-18',
#   'tl': {'@f': 'N', '@t': 'p', '@o': '800456', '@c': 'RE', '@n': '16523'},
#   'ar': {'@pt': '2508271633',
#    '@pp': '9',
#    '@l': '50',
#    '@ppth': 'Leipzig Hbf|Leipzig-Engelsdorf|Borsdorf(Sachs)|Wurzen|Kühren|Dahlen(Sachs)|Oschatz|Riesa|Glaubitz(Riesa)|Nünchritz|Priestewitz|Niederau|Weinböhla Hp|Coswig(b Dresden)|Radebeul Ost|Dresden-Neustadt|Dresden Mitte'}},
#  {'@id': '5533369185542660652-2508271547-10',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '30732'},
#   'ar': {'@pt': '2508271608',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271609',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Bischofsplatz|Dresden-Pieschen|Dresden-Trachau|Radebeul Ost|Radebeul-Weintraube|Radebeul-Kötzschenbroda|Radebeul-Zitzschewig|Coswig(b Dresden)|Neusörnewitz|Meißen|Meißen Altstadt|Meißen Triebischtal'}},
#  {'@id': '-4307725282420770361-2508271514-15',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '31746'},
#   'ar': {'@pt': '2508271558',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Bad Schandau|Königstein(Sächs Schw)|Kurort Rathen|Stadt Wehlen(Sachs)|Obervogelgesang|Pirna|Heidenau-Großsedlitz|Heidenau Süd|Heidenau|Dresden-Zschachwitz|Dresden-Niedersedlitz|Dresden-Dobritz|Dresden-Reick|Dresden-Strehlen'},
#   'dp': {'@pt': '2508271600',
#    '@pp': '14',
#    '@l': '1',
#    '@ppth': 'Dresden Freiberger Straße|Dresden Mitte|Dresden-Neustadt|Dresden Bischofsplatz|Dresden-Pieschen|Dresden-Trachau|Radebeul Ost|Radebeul-Weintraube|Radebeul-Kötzschenbroda|Radebeul-Zitzschewig|Coswig(b Dresden)|Neusörnewitz|Meißen|Meißen Altstadt|Meißen Triebischtal'}},
#  {'@id': '2536496346542639873-2508271601-1',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '8004L1', '@c': 'S', '@n': '16753'},
#   'dp': {'@pt': '2508271601',
#    '@pp': '10',
#    '@l': '8',
#    '@ppth': 'Dresden Mitte|Dresden-Neustadt|Dresden Industriegelände|Dresden-Klotzsche|Langebrück(Sachs)|Radeberg|Großröhrsdorf|Pulsnitz Süd|Pulsnitz|Bischheim-Gersdorf|Kamenz(Sachs)'}},
#  {'@id': '-7036206011879593139-2508271618-8',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '32749'},
#   'ar': {'@pt': '2508271638',
#    '@pp': '13',
#    '@l': '2',
#    '@ppth': 'Dresden Flughafen|Dresden Grenzstraße|Dresden-Klotzsche|Dresden Industriegelände|Dresden-Neustadt|Dresden Mitte|Dresden Freiberger Straße'},
#   'dp': {'@pt': '2508271640',
#    '@pp': '13',
#    '@l': '2',
#    '@ppth': 'Dresden-Strehlen|Dresden-Reick|Dresden-Dobritz|Dresden-Niedersedlitz|Dresden-Zschachwitz|Heidenau|Heidenau Süd|Heidenau-Großsedlitz|Pirna'}},
#  {'@id': '6028872490816230904-2508271328-11',
#   'tl': {'@f': 'N', '@t': 'p', '@o': 'CXRE', '@c': 'RE', '@n': '74021'},
#   'ar': {'@pt': '2508271604',
#    '@pp': '6',
#    '@l': '3',
#    '@ppth': 'Hof Hbf|Plauen(Vogtl) ob Bf|Reichenbach(Vogtl) ob Bf|Zwickau(Sachs)Hbf|Glauchau(Sachs)|Hohenstein-Ernstthal|Chemnitz Hbf|Flöha|Freiberg(Sachs)|Tharandt'}},
#  {'@id': '8897297547199763902-2508271547-16',
#   'tl': {'@f': 'S', '@t': 'p', '@o': '800469', '@c': 'S', '@n': '31749'},
#   'ar': {'@pt': '2508271627',
#    '@pp': '13',
#    '@l': '1',
#    '@ppth': 'Meißen Triebischtal|Meißen Altstadt|Meißen|Neusörnewitz|Coswig(b Dresden)|Radebeul-Zitzschewig|Radebeul-Kötzschenbroda|Radebeul-Weintraube|Radebeul Ost|Dresden-Trachau|Dresden-Pieschen|Dresden Bischofsplatz|Dresden-Neustadt|Dresden Mitte|Dresden Freiberger Straße'},
#   'dp': {'@pt': '2508271629',
#    '@pp': '13',
#    '@l': '1',
#    '@ppth': 'Dresden-Strehlen|Dresden-Reick|Dresden-Dobritz|Dresden-Niedersedlitz|Dresden-Zschachwitz|Heidenau|Heidenau Süd|Heidenau-Großsedlitz|Pirna|Obervogelgesang|Stadt Wehlen(Sachs)|Kurort Rathen|Königstein(Sächs Schw)|Bad Schandau'}},
#  {'@id': '-3155492482336516582-2508271221-11',
#   'tl': {'@f': 'F', '@t': 'p', '@o': '80', '@c': 'IC', '@n': '2179'},
#   'ar': {'@pt': '2508271627',
#    '@pp': '1',
#    '@ppth': 'Rostock Hbf|Waren(Müritz)|Neustrelitz Hbf|Oranienburg|Berlin Gesundbrunnen|Berlin Hbf|Berlin Südkreuz|Doberlug-Kirchhain|Elsterwerda|Dresden-Neustadt'}}]

# %%
# station_name = input("Station name: ")
# date_str     = input("Date (YYYY-MM-DD): ")
# hour_str     = input("Hour (00-23): ")
station_name = "Dresden Hbf"
date_str     = datetime.today().date()
hour_str     = datetime.now().hour

dt = datetime.strptime(f"{date_str} {hour_str}", "%Y-%m-%d %H")

eva = search_station(station_name)
print(f"EVA for {station_name}: {eva}")
plan = xmltodict.parse(get_plan(eva, dt))


# destinations = []
# departure_times = []
# train_cat = []

services = plan['timetable']["s"]

rows=[]

for service in services:
    tl = service.get("tl", {})
    dp = service.get("dp", {})



# Prefer explicit destination if available
    dest = dp.get["@pde"]
    if not dest:
        path = dp.get("@ppth") or ""
        if path:
            dest = path.split("|")[-1]

    # if dest:
    #     destinations.append(dest)

# Get planned departure time for each train
    time = dp.get("@pt")
    hhmm = None
    dt_obj = None
    if pt and len(pt) == 10:  # YYMMDDHHMM
        dt_obj = datetime.strptime(pt, "%y%m%d%H%M")
        hhmm = dt_obj.strftime("%H:%M")

    # if "@pt" in dp:
    #     time = dp["@pt"]
    # else:
    #     time = ""

    # if time:
    #     departure_times.append((datetime.strptime(time, "%Y%m%d%H%M").strftime("%H:%M")))

# I also want the train category
    cat = tl.get("@c")

    if dest and hhmm and cat:
        rows.append((dt_obj, dest, hhmm, cat))

    print (rows)
    # if "@c" in tl:
    #     cat = tl["@c"]
    # else:
    #     cat = ""

    # if cat:
    #     train_cat.append(cat)
# Out:
#   Cell In[44], line 30
#     dest = dp.get["@pde"]
#     ^
# IndentationError: unexpected indent
